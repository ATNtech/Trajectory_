# %%
from bs4 import BeautifulSoup
import urllib
import csv
import numpy as np

url = 'http://www.vsu.ru/sveden/education/oop.html#bak2020'
html = urllib.request.urlopen(url)
soup = BeautifulSoup(html)
#print(soup)
tablediv = soup.find("div", {"id":"tab2020"})
table = tablediv.find("table")
#print(table)
#print(table)
# python3 just use th.text
#headers = [th.text for th in table.select("tr td")]
table_contents = []   # store your table here
rows = table.find_all("tr")
for tr in rows:
#    if rows.index(tr) == 0 : 
        
        row_cells = [ th.getText().strip() for th in tr.find_all('th') if th.getText().strip() != '']
#        row_cells = [ th.getText().strip() for th in tr.find_all('th') if th.getText().strip() != '' ]  
#    else : 
#        td = list(filter(lambda x: not x.get('colspan'), td))
#        for data in tr.find_all("td", {"itemprop": "opMain"||"educationPlan"||"educationShedule"||"adEducationAnnotation"}):
          
        row_cells = ([ tr.find('th').getText() ] if tr.find('th') else []  ) + [ td.getText().strip() for td in tr.find_all('td') if not td.get('colspan')]
                 
        if len(row_cells) > 1 : 
            table_contents += [ row_cells ]

opMain = []
for data in table.find_all("td", {"itemprop": "opMain"}):
    for a in data.find_all('a'):
           opMain.append(a.get('href'))
#print(opMain)
#print(table_contents)

#print(headers)
#table table-stripped table-responsive table-hover table-bordered oop-table
#with open("vsu_programmes.csv", "w") as f:
#    wr = csv.writer(f)
#    wr.writerows(table_contents)
#    wr.writerows([[td.text.encode("utf-8") for td in row.find_all("td")] for row in table.select("tr + tr")])
#with open("vsu_programmes.csv", "w", newline='', encoding="utf-8") as csvfile:
#    writer = csv.writer(csvfile)
#    writer.writerows(table_contents)
# Out:
# [['Код', 'Наименование специальности, направление подготовки', 'Уровень образования', 'Реализуемые формы обучения', 'Описание ООП', 'Учебный план', 'Аннотации рабочих программ дисциплин с приложением копий', 'Календарный учебный график', 'Методические и иные документы', 'Информации о практиках', 'Использование электронного обучения'], ['01.06.01', 'Математика и механика (направленность "Вещественный, комплексный и функциональный анализ")', 'высшее образование – подготовка кадров высшей квалификации', 'очная', 'Описание ООП', 'Уч. план ООП', 'Аннотация к ООП', 'Уч. график ООП', 'Нет', 'Нет', 'Да'], ['01.06.01', 'Математика и механика (направленность "Вещественный, комплексный и функциональный анализ")', 'высшее образование – подготовка кадров высшей квалификации', 'очная', 'Описание АОП', 'Уч. план АОП', 'Аннотация к АОП', 'Уч. график АОП', 'Нет', 'Нет', 'Да'], ['01.06.01', 'Математика и механика (направленность "Дифференциальные уравнения, динамические системы и оптимальное управле
# ...

# %%
for i in range(1, 286):
     table_contents[i][4]=opMain[i-1]
print(len(table_contents))
#print(table_contents)
# Out:
# 395

# %%
with open("vsu_programmes.csv", "w", newline='', encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(table_contents)

# %%
len(opMain)
# Out:
# 286

# %%
from bs4 import BeautifulSoup
import urllib
import csv
import numpy as np

url = 'https://abiturientu.kai.ru/obrazovatel-nye-programmy'
html = urllib.request.urlopen(url)
soup = BeautifulSoup(html, 'html.parser')

      
#    x.append(data.get('href'))
#len(soup)
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="aui ltr" dir="ltr" lang="ru-RU">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <link href="https://abiturientu.kai.ru/pk-theme/images/favicon.ico" rel="Shortcut Icon"/>
# <link href="https://abiturientu.kai.ru/obrazovatel-nye-programmy" rel="canonical"/>
# <link class="lfr-css-file" href="https://abiturientu.kai.ru/pk-theme/css/aui.css?browserId=other&amp;themeId=pktheme_WAR_pktheme&amp;minifierType=css&amp;languageId=ru_RU&amp;b=6205&amp;t=1628240338000" rel="stylesheet" type="text/css"/>
# <link href="/html/css/main.css?browserId=other&amp;themeId=pktheme_WAR_pktheme&amp;minifierType=css&amp;languageId=ru_RU&amp;b=6205&amp;t=1452598584000" rel="stylesheet" type="text/css"/>
# <link href="https://abiturientu.kai.ru/html/portlet/journal_content/css/main.css?browserId=other&amp;themeId=pktheme_WAR_pktheme&amp;minifierType=css&amp;languageId=ru_RU&amp;b=6205&amp;t=1629566153000" rel="stylesheet" type="text/css"/>
# ...

# %%
x=[]
for data in soup.find_all("script"):
#    for data2 in data.find("var")
    x.append(data)
print(x)
# Out:
# [<script type="text/javascript">
# 	// <![CDATA[
# 		var Liferay = {
# 			Browser: {
# 				acceptsGzip: function() {
# 					return false;
# 				},
# 				getMajorVersion: function() {
# 					return 0.0;
# 				},
# 				getRevision: function() {
# 					return "";
# 				},
# 				getVersion: function() {
# 					return "";
# 				},
# 				isAir: function() {
# 					return false;
# 				},
# 				isChrome: function() {
# 					return false;
# 				},
# 				isFirefox: function() {
# 					return false;
# 				},
# 				isGecko: function() {
# 					return false;
# 				},
# 				isIe: function() {
# 					return false;
# 				},
# 				isIphone: function() {
# 					return false;
# 				},
# 				isLinux: function() {
# 					return false;
# 				},
# 				isMac: function() {
# 					return false;
# 				},
# 				isMobile: function() {
# 					return false;
# 				},
# 				isMozilla: function() {
# 					return false;
# 				},
# 				isOpera: function() {
# 					return false;
# 				},
# 				isRtf: function() {
# ...

# %%
x=[]
x.append([{"name": "Энерго- и ресурсоэффективные технологии","href": "https://abiturientu.kai.ru/13.03.01","code": "13.03.01 Теплоэнергетика и теплотехника","img": "/documents/10181/9630203/iante_s.png/12b2e66f-40b2-48ad-8baf-73764e617a37?t=1523519802867","inst": "Институт авиации, наземного транспорта и энергетики","educationType": "Бакалавриат","educationForms": [{"name": "Очная","budget": true,"price": 134492}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Физика", "mark": "Ф"}, {"title": "Информатика", "mark": "Инф"}],"militaryDepartment": true}, {"name": "Паро- и газотурбинные установки. Автомобильные двигатели","href": "https://abiturientu.kai.ru/13.03.03","code": "13.03.03 Энергетическое машиностроение","img": "/documents/10181/9630203/iante_s.png/12b2e66f-40b2-48ad-8baf-73764e617a37?t=1523519802867","inst": "Институт авиации, наземного транспорта и энергетики","educationType": "Бакалавриат","educationForms": [{"name": "Очная","budget": true,"price": 134492}, {"name": "Заочная","budget": false,"price": 50064}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Физика", "mark": "Ф"}, {"title": "Информатика", "mark": "Инф"}],"militaryDepartment": true}, {"name": "Современные сварочные материалы, технологии, оборудование и диагностика","href": "https://abiturientu.kai.ru/15.03.01","code": "15.03.01 Машиностроение","img": "/documents/10181/9630203/iante_s.png/12b2e66f-40b2-48ad-8baf-73764e617a37?t=1523519802867","inst": "Институт авиации, наземного транспорта и энергетики","educationType": "Бакалавриат","educationForms": [{"name": "Очная","budget": true,"price": 134492}, {"name": "Заочная","budget": false,"price": 50064}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Физика", "mark": "Ф"}, {"title": "Информатика", "mark": "Инф"}],"militaryDepartment": true}, {"name": "Технология машиностроения","href": "https://abiturientu.kai.ru/15.03.05","code": "15.03.05 Конструкторско-технологическое обеспечение машиностроительных производств","img": "/documents/10181/9630203/iante_s.png/12b2e66f-40b2-48ad-8baf-73764e617a37?t=1523519802867","inst": "Институт авиации, наземного транспорта и энергетики","educationType": "Бакалавриат","educationForms": [{"name": "Очная","budget": true,"price": 134492}, {"name": "Заочная","budget": true,"price": 50064}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Физика", "mark": "Ф"}, {"title": "Информатика", "mark": "Инф"}],"militaryDepartment": true}, {"name": "Технологии производства авиакосмической и беспилотной техники из композиционных материалов. Авиакосмическое материаловедение","href": "https://abiturientu.kai.ru/22.03.01","code": "22.03.01 Материаловедение и технологии материалов","img": "/documents/10181/9630203/iante_s.png/12b2e66f-40b2-48ad-8baf-73764e617a37?t=1523519802867","inst": "Институт авиации, наземного транспорта и энергетики","educationType": "Бакалавриат","educationForms": [{"name": "Очная","budget": true,"price": 134492}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Физика", "mark": "Ф"}, {"title": "Информатика", "mark": "Инф"}, {"title": "Химия", "mark": "Х"}],"militaryDepartment": true}, {"name": "Автомобильный транспорт. Сервис и эксплуатация","href": "https://abiturientu.kai.ru/23.03.03","code": "23.03.03 Эксплуатация транспортно-технологических машин и комплексов","img": "/documents/10181/9630203/iante_s.png/12b2e66f-40b2-48ad-8baf-73764e617a37?t=1523519802867","inst": "Институт авиации, наземного транспорта и энергетики","educationType": "Бакалавриат","educationForms": [{"name": "Очная","budget": true,"price": 134492}, {"name": "Заочная","budget": false,"price": 50064}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Физика", "mark": "Ф"}, {"title": "Информатика", "mark": "Инф"}],"militaryDepartment": true}, {"name": "Авиастроение","href": "https://abiturientu.kai.ru/24.03.04","code": "24.03.04 Авиастроение","img": "/documents/10181/9630203/iante_s.png/12b2e66f-40b2-48ad-8baf-73764e617a37?t=1523519802867","inst": "Институт авиации, наземного транспорта и энергетики","educationType": "Бакалавриат","educationForms": [{"name": "Очная","budget": true,"price": 164417}, {"name": "Очно-заочная","budget": true,"price": null}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Физика", "mark": "Ф"}, {"title": "Информатика", "mark": "Инф"}],"militaryDepartment": true}, {"name": "Двигатели летательных аппаратов","href": "https://abiturientu.kai.ru/24.03.05","code": "24.03.05 Двигатели летательных аппаратов","img": "/documents/10181/9630203/iante_s.png/12b2e66f-40b2-48ad-8baf-73764e617a37?t=1523519802867","inst": "Институт авиации, наземного транспорта и энергетики","educationType": "Бакалавриат","educationForms": [{"name": "Очная","budget": true,"price": 164417}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Физика", "mark": "Ф"}, {"title": "Информатика", "mark": "Инф"}],"militaryDepartment": true}, {"name": "Обслуживание судов и двигателей. Обеспечение безопасности полетов","href": "https://abiturientu.kai.ru/25.03.01","code": "25.03.01 Техническая эксплуатация летательных аппаратов и двигателей","img": "/documents/10181/9630203/iante_s.png/12b2e66f-40b2-48ad-8baf-73764e617a37?t=1523519802867","inst": "Институт авиации, наземного транспорта и энергетики","educationType": "Бакалавриат","educationForms": [{"name": "Очная","budget": false,"price": 164417}, {"name": "Заочная","budget": false,"price": 86569}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Физика", "mark": "Ф"}, {"title": "Информатика", "mark": "Инф"}],"militaryDepartment": true}, {"name": "Кораблестроение","href": "https://abiturientu.kai.ru/26.03.02","code": "26.03.02 Кораблестроение, океанотехника и системотехника объектов морской инфраструктуры","img": "/documents/10181/9630203/iante_s.png/12b2e66f-40b2-48ad-8baf-73764e617a37?t=1523519802867","inst": "Институт авиации, наземного транспорта и энергетики","educationType": "Бакалавриат","educationForms": [{"name": "Очная","budget": true,"price": 164417}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Физика", "mark": "Ф"}, {"title": "Информатика", "mark": "Инф"}],"militaryDepartment": true}, {"name": "Ракетные двигатели","href": "https://abiturientu.kai.ru/24.05.02","code": "24.05.02 Проектирование авиационных и ракетных двигателей","img": "/documents/10181/9630203/iante_s.png/12b2e66f-40b2-48ad-8baf-73764e617a37?t=1523519802867","inst": "Институт авиации, наземного транспорта и энергетики","educationType": "Специалитет","educationForms": [{"name": "Очная","budget": true,"price": 164417}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Физика", "mark": "Ф"}, {"title": "Информатика", "mark": "Инф"}],"militaryDepartment": true}, {"name": "
img": "/documents/10181/9630203/iret_s.png/f821fc72-dd36-451f-b0ff-4d9efb306309?t=1523519801810","inst": "Институт радиоэлектроники и телекоммуникаций","educationType": "Бакалавриат","educationForms": [{"name": "Очная","budget": true,"price": 134492}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Физика", "mark": "Ф"}, {"title": "Информатика", "mark": "Инф"}],"militaryDepartment": true}, {"name": "Системы передачи и обработки информации, управления, навигации и радиоэлектронной борьбы","href": "https://abiturientu.kai.ru/11.05.01","code": "11.05.01 Радиоэлектронные системы и комплексы","img": "/documents/10181/9630203/iret_s.png/f821fc72-dd36-451f-b0ff-4d9efb306309?t=1523519801810","inst": "Институт радиоэлектроники и телекоммуникаций","educationType": "Специалитет","educationForms": [{"name": "Очная","budget": true,"price": 134492}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Физика", "mark": "Ф"}, {"title": "Информатика", "mark": "Инф"}],"militaryDepartment": true}, {"name": "Инфокоммуникационные системы и их информационная защита","href": "https://abiturientu.kai.ru/25.05.03","code": "25.05.03 Техническая эксплуатация транспортного радиооборудования","img": "/documents/10181/9630203/iret_s.png/f821fc72-dd36-451f-b0ff-4d9efb306309?t=1523519801810","inst": "Институт радиоэлектроники и телекоммуникаций","educationType": "Специалитет","educationForms": [{"name": "Очная","budget": true,"price": 300819}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Физика", "mark": "Ф"}, {"title": "Информатика", "mark": "Инф"}],"militaryDepartment": true}, {"name": "Финансовые технологии","href": "https://abiturientu.kai.ru/27.03.05","code": "27.03.05 Инноватика","img": "/documents/10181/9630203/ieust_s.png/d56bab9b-53b2-4d2a-b0a2-29c6dfc06d5f?t=1523519803093","inst": "Институт инженерной экономики и предпринимательства","educationType": "Бакалавриат","educationForms": [{"name": "Очная","budget": true,"price": 134492}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Физика", "mark": "Ф"}, {"title": "Информатика", "mark": "Инф"}],"militaryDepartment": true}, {"name": "Экономика и управление цифровым предприятием. Инвестиционное проектирование. Промышленная коммерция","href": "https://abiturientu.kai.ru/38.03.01","code": "38.03.01 Экономика","img": "/documents/10181/9630203/ieust_s.png/d56bab9b-53b2-4d2a-b0a2-29c6dfc06d5f?t=1523519803093","inst": "Институт инженерной экономики и предпринимательства","educationType": "Бакалавриат","educationForms": [{"name": "Очная","budget": true,"price": 116530}, {"name": "Очно-заочная","budget": false,"price": null}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Обществознание", "mark": "О"}, {"title": "Иностранный", "mark": "Ин"}],"militaryDepartment": true}, {"name": "Управление проектами. Производственный менеджмент","href": "https://abiturientu.kai.ru/38.03.02","code": "38.03.02 Менеджмент","img": "/documents/10181/9630203/ieust_s.png/d56bab9b-53b2-4d2a-b0a2-29c6dfc06d5f?t=1523519803093","inst": "Институт инженерной экономики и предпринимательства","educationType": "Бакалавриат","educationForms": [{"name": "Очная","budget": true,"price": 116530}, {"name": "Очно-заочная","budget": false,"price": null}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Обществознание", "mark": "О"}, {"title": "Иностранный", "mark": "Ин"}],"militaryDepartment": true}, {"name": "Управление человеческими ресурсами","href": "https://abiturientu.kai.ru/38.03.03","code": "38.03.03 Управление персоналом","img": "/documents/10181/9630203/ieust_s.png/d56bab9b-53b2-4d2a-b0a2-29c6dfc06d5f?t=1523519803093","inst": "Институт инженерной экономики и предпринимательства","educationType": "Бакалавриат","educationForms": [{"name": "Очная","budget": false,"price": 116530}, {"name": "Очно-заочная","budget": false,"price": null}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Обществознание", "mark": "О"}, {"title": "Иностранный", "mark": "Ин"}],"militaryDepartment": true}, {"name": "Коммерческая разработка и технологическое предпринимательство","href": "https://abiturientu.kai.ru/09.03.01_1","code": "09.03.01 Информатика и вычислительная техника","img": "/documents/10181/9630203/iktzi_s.png/41702a93-6f3d-4665-98e9-d696d17bba5f?t=1523519803357","inst": "Высшая школа прикладных информационных технологий","educationType": "Бакалавриат","educationForms": [{"name": "Очная","budget": true,"price": 134492}],"tests": [{"title": "Математика", "mark": "М"}, {"title": "Русский язык", "mark": "Р"}, {"title": "Физика", "mark": "Ф"}, {"title": "Информатика", "mark": "Инф"}],"militaryDepartment": true}, {"name": "15.02.15 Технология металлообрабатывающего производства (на базе 9 классов)","href": "https://abiturientu.kai.ru/15.02.15","code": "15.02.15 Технология металлообрабатывающего производства","img": "/documents/10181/9630203/iante_s.png/12b2e66f-40b2-48ad-8baf-73764e617a37?t=1523519802867","inst": "Институт авиации, наземного транспорта и энергетики","educationType": "СПО","educationForms": [{"name": "Очная","budget": true,"price": 64346}],"tests": "","militaryDepartment": true}, {"name": "23.02.07 Техническое обслуживание и ремонт двигателей, систем и агрегатов автомобилей (на базе 9 классов)","href": "https://abiturientu.kai.ru/23.02.07","code": "23.02.07 Техническое обслуживание и ремонт двигателей, систем и агрегатов автомобилей","img": "/documents/10181/9630203/iante_s.png/12b2e66f-40b2-48ad-8baf-73764e617a37?t=1523519802867","inst": "Институт авиации, наземного транспорта и энергетики","educationType": "СПО","educationForms": [{"name": "Очная","budget": true,"price": 64346}],"tests": "","militaryDepartment": true}, {"name": "27.02.07 Управление качеством продукции, процессов и услуг (по отраслям) (на базе 9 и 11 классов)","href": "https://abiturientu.kai.ru/27.02.07","code": "27.02.07 Управление качеством продукции, процессов и услуг (по отраслям)","img": "/documents/10181/9630203/iante_s.png/12b2e66f-40b2-48ad-8baf-73764e617a37?t=1523519802867","inst": "Институт авиации, наземного транспорта и энергетики","educationType": "СПО","educationForms": [{"name": "Очная","budget": true,"price": 64346}],"tests": "","militaryDepartment": true}, {"name": "38.02.01 Экономика и бухгалтерский учет (по отраслям) (на базе 9 и 11 классов)","href": "https://abiturientu.kai.ru/38.02.01","code": "38.02.01 Экономика и бухгалтерский учет (по отраслям)","img": "/documents/10181/9630203/iante_s.png/12b2e66f-40b2-48ad-8baf-73764e617a37?t=1523519802867","inst": "Институт авиации, наземного транспорта и энергетики","educationType": "СПО","educationForms": [{"name": "Очная","budget": false,"price": 59596}],"tests": "","militaryDepartment": true}, {"name": "09.02.06 Сетевое и системное администрирование (на базе 9 классов)","href": "https://abiturientu.kai.ru/09.02.06","code": "09.02.06 Сетевое и системное администрирование","img": "/documents/10181/9630203/iktzi_s.png/41702a93-6f3d-4665-98e9-d696d17bba5f?t=1523519803357","inst": "Институт компьютерных технологий и защиты информации","educationType": "СПО","educationForms": [{"name": "Очная","budget": true,"price": 64346}],"tests": "","militaryDepartment": true}, {"name": "09.02.07 Информационные системы и программирование (на базе 9 классов)","href": "https://abiturientu.kai.ru/09.02.07","code": "09.02.07 Информационные системы и программирование","img": "/documents/10181/9630203/iktzi_s.png/41702a93-6f3d-4665-98e9-d696d17bba5f?t=1523519803357","inst": "Институт компьютерных технологий и защиты информации","educationType": "СПО","educationForms": [{"name": "Очная","budget": true,"price": 64346}],"tests": "","militaryDepartment": true}, {"name": "10.02.05 Обеспечение информационной безопасности автоматизированных систем (на базе 9 классов)","href": "https://abiturientu.kai.ru/10.02.05","code": "10.02.05 Обеспечение информационной безопасности автоматизированных систем","img": "/documents/10181/9630203/iktzi_s.png/41702a93-6f3d-4665-98e9-d696d17bba5f?t=1523519803357","inst": "Институт компьютерных технологий и защиты информации","educationType":
img": "/documents/10181/9630203/iret_s.png/f821fc72-dd36-451f-b0ff-4d9efb306309?t=1523519801810","inst": "Институт радиоэлектроники и телекоммуникаций","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": true,"price": 143290}],"tests": [{"title": "Компьютерное тестирование","mark": "Компьютерное тестирование"}],"militaryDepartment": false}, {"name": "11.04.03 Конструирование и технология электронных средств","href": "https://abiturientu.kai.ru/11.04.03","code": "11.04.03 Конструирование и технология электронных средств","img": "/documents/10181/9630203/iret_s.png/f821fc72-dd36-451f-b0ff-4d9efb306309?t=1523519801810","inst": "Институт радиоэлектроники и телекоммуникаций","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": true,"price": 143290}],"tests": [{"title": "Компьютерное тестирование","mark": "Компьютерное тестирование"}],"militaryDepartment": false}, {"name": "11.04.04 Электроника и наноэлектроника","href": "https://abiturientu.kai.ru/11.04.04","code": "11.04.04 Электроника и наноэлектроника","img": "/documents/10181/9630203/iret_s.png/f821fc72-dd36-451f-b0ff-4d9efb306309?t=1523519801810","inst": "Институт радиоэлектроники и телекоммуникаций","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": true,"price": 143290}],"tests": [{"title": "Компьютерное тестирование","mark": "Компьютерное тестирование"}],"militaryDepartment": false}, {"name": "12.04.03 Фотоника и оптоинформатика","href": "https://abiturientu.kai.ru/12.04.03","code": "12.04.03 Фотоника и оптоинформатика","img": "/documents/10181/9630203/iret_s.png/f821fc72-dd36-451f-b0ff-4d9efb306309?t=1523519801810","inst": "Институт радиоэлектроники и телекоммуникаций","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": true,"price": 143290}, {"name": "Заочная","budget": false,"price": 52671}],"tests": [{"title": "Компьютерное тестирование","mark": "Компьютерное тестирование"}],"militaryDepartment": false}, {"name": "27.04.04 Управление в технических системах","href": "https://abiturientu.kai.ru/27.04.04_1","code": "27.04.04 Управление в технических системах","img": "/documents/10181/9630203/ieust_s.png/d56bab9b-53b2-4d2a-b0a2-29c6dfc06d5f?t=1523519803093","inst": "Институт инженерной экономики и предпринимательства","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": true,"price": 143290}],"tests": [{"title": "Междисциплинарный экзамен","mark": "Междисциплинарный экзамен"}],"militaryDepartment": false}, {"name": "27.04.05 Инноватика","href": "https://abiturientu.kai.ru/27.04.05","code": "27.04.05 Инноватика","img": "/documents/10181/9630203/ieust_s.png/d56bab9b-53b2-4d2a-b0a2-29c6dfc06d5f?t=1523519803093","inst": "Институт инженерной экономики и предпринимательства","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": true,"price": 143290}, {"name": "Заочная","budget": false,"price": 52671}],"tests": [{"title": "Междисциплинарный экзамен","mark": "Междисциплинарный экзамен"}],"militaryDepartment": false}, {"name": "27.04.06 Организация и управление наукоемкими производствами","href": "https://abiturientu.kai.ru/27.04.06","code": "27.04.06 Организация и управление наукоемкими производствами","img": "/documents/10181/9630203/ieust_s.png/d56bab9b-53b2-4d2a-b0a2-29c6dfc06d5f?t=1523519803093","inst": "Институт инженерной экономики и предпринимательства","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": true,"price": 143290}],"tests": [{"title": "Междисциплинарный экзамен","mark": "Междисциплинарный экзамен"}],"militaryDepartment": false}, {"name": "38.04.01 Экономика","href": "https://abiturientu.kai.ru/38.04.01","code": "38.04.01 Экономика","img": "/documents/10181/9630203/ieust_s.png/d56bab9b-53b2-4d2a-b0a2-29c6dfc06d5f?t=1523519803093","inst": "Институт инженерной экономики и предпринимательства","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": true,"price": null}, {"name": "Заочная","budget": false,"price": 69881}],"tests": [{"title": "Междисциплинарный экзамен","mark": "Междисциплинарный экзамен"}],"militaryDepartment": false}, {"name": "38.04.02 Менеджмент","href": "https://abiturientu.kai.ru/38.04.02","code": "38.04.02 Менеджмент","img": "/documents/10181/9630203/ieust_s.png/d56bab9b-53b2-4d2a-b0a2-29c6dfc06d5f?t=1523519803093","inst": "Институт инженерной экономики и предпринимательства","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": true,"price": null}],"tests": [{"title": "Междисциплинарный экзамен","mark": "Междисциплинарный экзамен"}],"militaryDepartment": false}, {"name": "Communication and Signal Processing","href": "https://abiturientu.kai.ru/11.04.02","code": "11.04.02 Инфокоммуникационные технологии и системы связи","img": "/documents/10181/9630203/griat_s.png/d179d536-2828-4a2e-a789-349ba4dc42e1?t=1582014323687","inst": "Германо-Российский институт новых технологий","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": true,"price": 143290}],"tests": [{"title": "Собеседование по Skype","mark": "Собеседование по Skype"}],"militaryDepartment": false}, {"name": "Research in Computer and Systems Engineering","href": "https://abiturientu.kai.ru/09.04.01","code": "09.04.01 Информатика и вычислительная техника","img": "/documents/10181/9630203/griat_s.png/d179d536-2828-4a2e-a789-349ba4dc42e1?t=1582014323687","inst": "Германо-Российский институт новых технологий","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": true,"price": 143290}],"tests": [{"title": "Собеседование по Skype","mark": "Собеседование по Skype"}],"militaryDepartment": false}, {"name": "Intelligent Data Processing","href": "https://abiturientu.kai.ru/09.04.01","code": "09.04.01 Информатика и вычислительная техника","img": "/documents/10181/9630203/griat_s.png/d179d536-2828-4a2e-a789-349ba4dc42e1?t=1582014323687","inst": "Германо-Российский институт новых технологий","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": true,"price": 143290}],"tests": [{"title": "Собеседование по Skype","mark": "Собеседование по Skype"}],"militaryDepartment": false}, {"name": "Electrical Engineering and Information Technology","href": "https://abiturientu.kai.ru/13.04.02","code": "13.04.02 Электроэнергетика и электротехника","img": "/documents/10181/9630203/griat_s.png/d179d536-2828-4a2e-a789-349ba4dc42e1?t=1582014323687","inst": "Германо-Российский институт новых технологий","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": true,"price": 143290}],"tests": [{"title": "Собеседование по Skype","mark": "Собеседование по Skype"}],"militaryDepartment": false}, {"name": "Chemical and Energy Engineering","href": "https://abiturientu.kai.ru/13.04.01","code": "13.04.01 Теплоэнергетика и теплотехника","img": "/documents/10181/9630203/griat_s.png/d179d536-2828-4a2e-a789-349ba4dc42e1?t=1582014323687","inst": "Германо-Российский институт новых технологий","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": true,"price": 143290}],"tests": [{"title": "Собеседование по Skype","mark": "Собеседование по Skype"}],"militaryDepartment": false}, {"name": "Systems Engineering and Engineering Cybernetics","href": "https://abiturientu.kai.ru/27.04.04","code": "27.04.04 Управление в технических системах","img": "/documents/10181/9630203/griat_s.png/d179d536-2828-4a2e-a789-349ba4dc42e1?t=1582014323687","inst": "Германо-Российский институт новых технологий","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": true,"price": 143290}],"tests": [{"title": "Собеседование по Skype","mark": "Собеседование по Skype"}],"militaryDepartment": false}, {"name": "Embedded Systems","href": "https://abiturientu.kai.ru/11.04.01","code": "11.04.01 Радиотехника","img": "/documents/10181/9630203/griat_s.png/d179d536-2828-4a2e-a789-349ba4dc42e1?t=1582014323687","inst": "Германо-Российский институт новых технологий","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": true,"price": 143290}],"tests": [{"title": "Собеседование по Skype","mark": "Собеседование по Skype"}],"militaryDepartment": false}, {"name": "Advanced Quantum Technologies","href": "https://abiturientu.kai.ru/12.04.03","code": "12.04.03 Фотоника и оптоинформатика","img": "/documents/10181/9630203/griat_s.png/d179d536-2828-4a2e-a789-349ba4dc42e1?t=1582014323687","inst": "Германо-Российский институт новых технологий","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": false,"price": 143290}],"tests": [{"title": "Собеседование по Skype","mark": "Собеседование по Skype"}],"militaryDepartment": false}, {"name": "Automotive Engineering","href": "https://abiturientu.kai.ru/23.04.02","code": "23.04.02 Наземные транспортно-технологические комплексы","img": "/documents/10181/9630203/griat_s.png/d179d536-2828-4a2e-a789-349ba4dc42e1?t=1582014323687","inst": "Германо-Российский институт новых технологий","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": false,"price": 143290}],"tests": [{"title": "Собеседование по Skype","mark": "Собеседование по Skype"}],"militaryDepartment": false}, {"name": "System Engineering and Engineering Cybernetics","href": "https://abiturientu.kai.ru/27.04.04","code": "27.04.04 Управление в технических системах","img": "/documents/10181/9630203/griat_s.png/d179d536-2828-4a2e-a789-349ba4dc42e1?t=1582014323687","inst": "Германо-Российский институт новых технологий","educationType": "Магистратура","educationForms": [{"name": "Очная","budget": true,"price": 143290}],"tests": [{"title": "Собеседование по Skype","mark": "Собеседование по Skype"}],"militaryDepartment": false}])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-1defc5866e58> in <module>
#       1 x=[]
# ...
